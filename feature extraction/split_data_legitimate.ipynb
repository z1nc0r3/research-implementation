# %%
import pandas as pd
import requests

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_csv("/content/drive/MyDrive/Research content/data/dataset_phishing.csv")

# %%
legi = df[df["status"] == "legitimate"]
pish = df[df["status"] == "phishing"]

# %%
pish.head()
# Out:
#                                                   url  length_url  \
# 1   http://shadetreetechnology.com/V4/validation/a...          77
# 2   https://support-appleld.com.secureupdate.duila...         126
# 5                    http://appleid.apple.com-app.es/          32
# 7   http://www.shadetreetechnology.com/V4/validati...          81
# 13                    http://html.house/l7ceeid6.html          31
#
#     length_hostname  ip  nb_dots  nb_hyphens  nb_at  nb_qm  nb_and  nb_or  \
# 1                23   1        1           0      0      0       0      0
# 2                50   1        4           1      0      1       2      0
# 5                24   0        3           1      0      0       0      0
# 7                27   1        2           0      0      0       0      0
# 13               10   0        2           0      0      0       0      0
#
#     ...  domain_in_title  domain_with_copyright  whois_registered_domain  \
# ...

# %%
# prompt: make a new df with 50 rows of legi df

legit = legi.sample(n = 10)
legit.shape
# Out:
# (10, 89)

# %%
legit.head()

# %%
def is_alive(url):
    try:
        res = requests.get(url, timeout=3)
        res.raise_for_status()
        return True
    except Exception as e:
        print(e)
        return False

# %%
result = pd.DataFrame(columns=["url"])

# %%
start = 0

# %%
for i in range(start, len(legi)):
  url = legi.iloc[i]["url"]
  print(start, url)

  if is_alive(url):
    result.loc[start] = url


  start += 1
# Out:
# Streaming output truncated to the last 5000 lines.
# 1630 https://www.tradingcardmint.com/
# 1631 http://www.newsnow.co.uk/h/Science/Archaeology
# 1632 http://www.pestworld.org/pest-guide/rodents/house-mice/
# 1633 http://www.domenicozaccagna.gov.it/
# HTTPConnectionPool(host='www.domenicozaccagna.gov.it', port=80): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x79b5cd59fb20>: Failed to resolve 'www.domenicozaccagna.gov.it' ([Errno -2] Name or service not known)"))
# 1634 http://blogs.worldbank.org/transport/three-factors-have-made-singapore-global-logistics-hub
# 1635 https://www.showplaceicon.com/browsing/cinemas/details/8146
# 1636 https://www.trophyrunners.de/
# 1637 http://photos.state.gov/libraries/laos/19452/pdfs/uspacom.pdf
# ...

# %%
start
# Out:
# 5715

# %%
result
# Out:
#                                                     url
# 0                 http://www.crestonwood.com/router.php
# 1                                    http://rgipt.ac.in
# 3                                   http://www.mutuo.it
# 4            http://vamoaestudiarmedicina.blogspot.com/
# 6     https://www.astrologyonline.eu/Astro_MemoNew/P...
# ...                                                 ...
# 5709  https://adnanboz.wordpress.com/2012/01/06/how-...
# 5710                          http://sheetdownload.com/
# 5711  http://www.answers.com/Q/What_are_the_sizes_of...
# 5713  https://www.facebook.com/Interactive-Televisio...
# 5714             http://www.mypublicdomainpictures.com/
#
# [4419 rows x 1 columns]

# %%
result.to_csv("online_phish.csv", index=False)

# %%
import urllib3
import bs4

urllib3.disable_warnings()

res = requests.get("https://tubipenlinea.click", allow_redirects=True, verify=False)

print(res.text)
# Out:
# <html> <head> <title>Amazon ECS Sample App</title> <style>body {margin-top: 40px; background-color: #333;} </style> </head><body> <div style=color:white;text-align:center> <h1>Amazon ECS Sample App</h1> <h2>Congratulations!</h2> <p>Your application is now running on a container in Amazon ECS.</p> </div></body></html>
