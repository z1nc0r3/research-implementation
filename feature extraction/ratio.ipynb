# %%
import pandas as pd

# !pip install tldextract
import tldextract

# %%
df = pd.read_csv('/content/drive/MyDrive/Research content/data/5_legit.csv')
df.head()
# Out:
#                                                  url  words  no_of_forms  \
# 0                                 http://rgipt.ac.in      2            1
# 1                                http://www.mutuo.it      4            1
# 2         http://vamoaestudiarmedicina.blogspot.com/      4            0
# 3  https://www.astrologyonline.eu/Astro_MemoNew/P...      7            0
# 4        https://www.lifewire.com/tcp-port-21-818146      6            4
#
#    no_of_iframes  missing_title  title_length  favicon  status  domain_length  \
# 0              0              0            12        1       0             11
# 1              0              0             6        1       0             12
# 2              0              0             4        1       0             34
# 3              0              0             5        0       0             22
# 4              2              0            10        1       0             16
#
#   domain_tld  ...  hyphens  single_slashes  commas  tlides  qms  ands  eqs  \
# 0      ac.in  ...        0               2       0       0    0     0    0
# 1         it  ...        0               2       0       0    0     0    0
# 2        com  ...        0               3       0       0    0     0    0
# 3         eu  ...        0               4       0       0    0     0    0
# 4        com  ...        3               3       0       0    0     0    0
#
#    underscores  percentages  www
# 0            0            0    0
# 1            0            0    1
# 2            0            0    0
# 3            1            0    1
# 4            0            0    1
#
# [5 rows x 30 columns]

# %%
def ratio(url):
  digits = sum(c.isdigit() for c in url)
  letters = sum(c.isalpha() for c in url)

  if digits == 0: return 0

  ratio = letters/digits
  return round(ratio, 2)

# %%
df['domain_ratio'] = ''
df['ratio'] = ''
df.head()
# Out:
#                                                  url  words  no_of_forms  \
# 0                                 http://rgipt.ac.in      2            1
# 1                                http://www.mutuo.it      4            1
# 2         http://vamoaestudiarmedicina.blogspot.com/      4            0
# 3  https://www.astrologyonline.eu/Astro_MemoNew/P...      7            0
# 4        https://www.lifewire.com/tcp-port-21-818146      6            4
#
#    no_of_iframes  missing_title  title_length  favicon  status  domain_length  \
# 0              0              0            12        1       0             11
# 1              0              0             6        1       0             12
# 2              0              0             4        1       0             34
# 3              0              0             5        0       0             22
# 4              2              0            10        1       0             16
#
#   domain_tld  ...  commas  tlides  qms  ands  eqs  underscores  percentages  \
# 0      ac.in  ...       0       0    0     0    0            0            0
# 1         it  ...       0       0    0     0    0            0            0
# 2        com  ...       0       0    0     0    0            0            0
# 3         eu  ...       0       0    0     0    0            1            0
# 4        com  ...       0       0    0     0    0            0            0
#
#    www  domain_ratio  ratio
# 0    0
# 1    1
# 2    0
# 3    1
# 4    1
#
# [5 rows x 32 columns]

# %%
for i in df.index:
    url = df.iloc[i]['url']
    ext = tldextract.extract(url)
    domain = ext.fqdn

    df.loc[i, 'domain_ratio'] = ratio(domain)
    df.loc[i, 'ratio'] = ratio(url)

# %%
df.head()
# Out:
#                                                  url  words  no_of_forms  \
# 0                                 http://rgipt.ac.in      2            1
# 1                                http://www.mutuo.it      4            1
# 2         http://vamoaestudiarmedicina.blogspot.com/      4            0
# 3  https://www.astrologyonline.eu/Astro_MemoNew/P...      7            0
# 4        https://www.lifewire.com/tcp-port-21-818146      6            4
#
#    no_of_iframes  missing_title  title_length  favicon  status  domain_length  \
# 0              0              0            12        1       0             11
# 1              0              0             6        1       0             12
# 2              0              0             4        1       0             34
# 3              0              0             5        0       0             22
# 4              2              0            10        1       0             16
#
#   domain_tld  ...  commas  tlides  qms  ands  eqs  underscores  percentages  \
# 0      ac.in  ...       0       0    0     0    0            0            0
# 1         it  ...       0       0    0     0    0            0            0
# 2        com  ...       0       0    0     0    0            0            0
# 3         eu  ...       0       0    0     0    0            1            0
# 4        com  ...       0       0    0     0    0            0            0
#
#    www  domain_ratio  ratio
# 0    0             0      0
# 1    1             0      0
# 2    0             0      0
# 3    1             0      0
# 4    1             0   3.25
#
# [5 rows x 32 columns]

# %%
df.to_csv('6_legit.csv', index=False)
