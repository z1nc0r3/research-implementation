# %%
import pandas as pd
import requests

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_csv("/content/drive/MyDrive/Research content/data/verified_phishing_online-20000.csv")

# %%
df.head()

# %%
def is_alive(url):
    try:
        res = requests.get(url, timeout=3)
        res.raise_for_status()
        return True
    except Exception as e:
        print(e)
        return False

# %%
result = pd.DataFrame(columns=["url"])

# %%
start = 0

# %%
for i in range(start, len(df)):
  url = df.iloc[i]["url"]
  print(start, url)

  if is_alive(url):
    result.loc[start] = url

  start += 1
# Out:
# Streaming output truncated to the last 5000 lines.
# 15365 https://ipfs.eth.aragon.network/ipfs/bafybeierhgmlb34447cx3m6wfniuvwcmbzi5ss5inmaeylk2vechgl5gv4
# 15366 https://cloudflare-ipfs.com/ipfs/bafybeierhgmlb34447cx3m6wfniuvwcmbzi5ss5inmaeylk2vechgl5gv4
# 15367 https://bafybeierhgmlb34447cx3m6wfniuvwcmbzi5ss5inmaeylk2vechgl5gv4.ipfs.cf-ipfs.com/
# 15368 https://cf-ipfs.com/ipfs/QmY7YmHNohot3ZeNAgAauHc6vnH3RyF6zt8TreM1VZrB5x
# 15369 https://bafybeierhgmlb34447cx3m6wfniuvwcmbzi5ss5inmaeylk2vechgl5gv4.ipfs.cf-ipfs.com
# 15370 https://ipfs.eth.aragon.network/ipfs/bafybeihox2fy2wit33cvzvxal3xw7nw7lnyr3s4dnffzlvqjyxpobisnxm/
# 15371 https://ipfs.eth.aragon.network/ipfs/bafybeihox2fy2wit33cvzvxal3xw7nw7lnyr3s4dnffzlvqjyxpobisnxm
# 15372 https://cloudflare-ipfs.com/ipfs/bafybeihox2fy2wit33cvzvxal3xw7nw7lnyr3s4dnffzlvqjyxpobisnxm
# 15373 https://cloudflare-ipfs.com/ipfs/bafybeihox2fy2wit33cvzvxal3xw7nw7lnyr3s4dnffzlvqjyxpobisnxm/
# ...

# %%
start

# %%
result
# Out:
#                                                      url
# 0      https://cert.reschedule.delivery.info.172-160-...
# 2      https://new.express.adobe.com/webpage/8ja7xtiE...
# 3                                https://lnkfi.re/xyBhG4
# 5      https://www.cakeresume.com/s--ti7Wd5TZ5_6VWabr...
# 8                       https://aramx-bahrain.yiff.fi/b/
# ...                                                  ...
# 19986  http://outlook.office7.zya.me/login.live.com_l...
# 19987                               https://w-up.com.au/
# 19996     https://recover-rycs10012964918531.start.page/
# 19997              https://instagram-security.pages.dev/
# 19998                               http://magiceden.com
#
# [15085 rows x 1 columns]

# %%
result.to_csv("online_phishing.csv", index=False)

# %%
import urllib3
import bs4

urllib3.disable_warnings()

res = requests.get("https://tubipenlinea.click", allow_redirects=True, verify=False)

print(res.text)
# Out:
# <html> <head> <title>Amazon ECS Sample App</title> <style>body {margin-top: 40px; background-color: #333;} </style> </head><body> <div style=color:white;text-align:center> <h1>Amazon ECS Sample App</h1> <h2>Congratulations!</h2> <p>Your application is now running on a container in Amazon ECS.</p> </div></body></html>
